# %%
 import sys
 print(sys.executable)
# Out:
# /opt/anaconda3/bin/python

# %%
import numpy as np
import pandas as pd
import os

# %%
class dataCleaning:
    def folderToDfs(folderpath):
        """returns list of dataframes from an input folder"""
        files = os.listdir(folderpath)
        df_list = []
        for file in files:
            if not file.startswith('.'):
                temp_df = pd.read_csv(folderpath+'/'+file)
                df_list.append(temp_df)
        return df_list
    
    def renameCols(dfs, colNames):
        """Takes list of data frames and dictionary of replacement colNames and and renames specifies columns"""
        for df in dfs:
            df.rename(columns=colNames, inplace=True)
    
    #     print(df.columns)
    def combineVertically(dfs):
        """Takes list of dataframes and returns a single dataframe of dfs stacked vertically"""
        stack = pd.concat(dfs, axis=0)
        stack['Date'] = pd.to_datetime(stack['Date'])
        return stack.sort_values('Date')

    def cleanedDailyAvg(dataFrame):
        """Takes a data frame. Averages variables by day"""
        temp = dataFrame[dataFrame['pH_total_scale']> 0]
        return temp.groupby(['Date']).mean()

# %%
ME_dfs = dataCleaning.folderToDfs('data/ME')
GA_dfs = dataCleaning.folderToDfs('data/GA')
FL_dfs = dataCleaning.folderToDfs('data/FL')

# %% [markdown]
# # Maine

# %%
columns = {
    "pH_SW":"pH_total_scale",
    "pH_SW (Total Scale)":"pH_total_scale",
    "pH (total scale)":"pH_total_scale",
    'CHL': "CHL (ug/l)",
    'xCO2  Air (wet) (umol/mol)':'xCO2 Air (wet) (umol/mol)',
    'xCO2  Air (wet) (umol/mol)': 'xCO2 Air (wet) (umol/mol)',
    'DOXY': 'DOXY (umol/kg)',
    'Licor Atm Pressure  (hPa)' : 'Licor Atm Pressure (hPa)',
    'NTU': 'NTU (NTU)',
    'fCO2  Air (sat) uatm' : 'fCO2 Air (sat) (uatm)',
    'fCO2  SW (sat) uatm': 'fCO2 SW (sat) (uatm)',
    'fCO2 Air (sat) uatm' : 'fCO2 Air (sat) (uatm)',
    'pCO2 Air (sat) uatm':'pCO2 Air (sat) (uatm)',
    'fCO2 SW (sat) uatm': 'fCO2 SW (sat) (uatm)',
    'fCO2  SW (sat) (uatm)': 'fCO2 SW (sat) (uatm)',
    'pCO2 SW (sat) uatm' : 'pCO2 SW (sat) (uatm)',
    'xCO2  SW (dry) (umol/mol)' : 'xCO2 SW (dry) (umol/mol)',
    'xCO2  SW (wet) (umol/mol)' : 'xCO2 SW (wet) (umol/mol)',
    'xCO2  Air (dry) (umol/mol)' : 'xCO2 Air (dry) (umol/mol)'
    
    
    
   
    
    
            }
# http://localhost:8890/notebooks/Documents/clark/s21/OceanpHDash/analysis/dataCleaning.ipynb#
dataCleaning.renameCols(ME_dfs, columns)
ME_DF = dataCleaning.combineVertically(ME_dfs)



ME_DF_AVG = dataCleaning.cleanedDailyAvg(ME_DF)

# %%
# ME_DF['Date'] = pd.to_datetime(ME_DF['Date'])
# ME_DF.sort_values('Date')
# ME_DF

# %% [markdown]
# # Georgia

# %%
# all the pH variables seem to have the same name
columns = {"pH (total scale)":"pH_total_scale"}

dataCleaning.renameCols(GA_dfs, columns)
GA_DF = dataCleaning.combineVertically(GA_dfs)
GA_DF_AVG = dataCleaning.cleanedDailyAvg(GA_DF)
GA_DF_AVG['pH_total_scale'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ME_DF_AVG.columns
# Out:
# Index(['Latitude', 'Longitude', 'xCO2 SW (wet) (umol/mol)', 'CO2 SW QF',
#        'H2O SW (mmol/mol)', 'xCO2 Air (wet) (umol/mol)', 'CO2 Air QF',
#        'H2O Air (mmol/mol)', 'Licor Atm Pressure (hPa)', 'Licor Temp (C)',
#        'MAPCO2 %O2', 'SST (C)', 'Salinity', 'xCO2 SW (dry) (umol/mol)',
#        'xCO2 Air (dry) (umol/mol)', 'fCO2 SW (sat) (uatm)',
#        'fCO2 Air (sat) (uatm)', 'dfCO2', 'pCO2 SW (sat) (uatm)',
#        'pCO2 Air (sat) (uatm)', 'dpCO2', 'pH_total_scale', 'pH_QF',
#        'CHL (ug/l)', 'CHL QF', 'NTU (NTU)', 'NTU QF', 'DOXY (umol/kg)',
#        'DOXY QF', 'QF_pH', 'pH QF'],
#       dtype='object')

# %%
GA_DF_AVG.columns
# Out:
# Index(['Latitude', 'Longitude', 'xCO2 SW (wet) (umol/mol)', 'CO2 SW QF',
#        'H2O SW (mmol/mol)', 'xCO2 Air (wet) (umol/mol)', 'CO2 Air QF',
#        'H2O Air (mmol/mol)', 'Licor Atm Pressure (hPa)', 'Licor Temp (C)',
#        'MAPCO2 %O2', 'SST (C)', 'Salinity', 'xCO2 SW (dry) (umol/mol)',
#        'xCO2 Air (dry) (umol/mol)', 'fCO2 SW (sat) (uatm)',
#        'fCO2 Air (sat) (uatm)', 'dfCO2', 'pCO2 SW (sat) (uatm)',
#        'pCO2 Air (sat) (uatm)', 'dpCO2', 'pH_total_scale', 'pH QF',
#        'CHL (ug/l)', 'CHL QF', 'NTU (NTU)', 'NTU QF', 'DOXY (umol/kg)',
#        'DOXY QF'],
#       dtype='object')

# %%
# This is how I can filter by a particular variable 
# ME_dfs[0][ME_dfs[0]['pH_SW'] > 0]

# %% [markdown]
# # Florida

# %%
FL_cols = {
   "pH_SW": "pH_total_scale",
    "pH_SW (Total Scale)": "pH_total_scale",
    "pH (total scale)": "pH_total_scale",
    "pH SW": "pH_total_scale",
    "pH_Total_Scale": "pH_total_scale",
#     'CHL': "CHL (ug/l)",
#     'xCO2 Air (wet) (umol/mol)': 'xCO2 Air (wet) (umol/mol)',
    
#     'Licor Atm Pressure  (hPa)': 'Licor Atm Pressure (hPa)',
#     'fCO2  Air (sat) uatm': 'fCO2 Air (sat) (uatm)',
#     'fCO2  SW (sat) uatm': 'fCO2 SW (sat) (uatm)',
#     # 'fCO2 Air (sat) uatm': 'fCO2 Air (sat) (uatm)',
#     'pCO2 Air (sat) uatm': 'pCO2 Air (sat) (uatm)',
#     # 'fCO2 SW (sat) uatm': 'fCO2 SW (sat) (uatm)',
#     # 'fCO2  SW (sat) (uatm)': 'fCO2 SW (sat) (uatm)',
#     'pCO2 SW (sat) uatm': 'pCO2 SW (sat) (uatm)',
    
    
#     'xCO2  Air (dry) (umol/mol)': 'xCO2 Air (dry) (umol/mol)',
#     'fCO2 Air (sat) uatm' : 'fCO2 Air (sat) (uatm)',
#     'fCO2 SW (sat) uatm' : 'fCO2 SW (sat) (uatm)'
    
    

}

dataCleaning.renameCols(FL_dfs, FL_cols)
FL_DF = dataCleaning.combineVertically(FL_dfs)
FL_DF_AVG= dataCleaning.cleanedDailyAvg(FL_DF)

FL_DF_AVG["pH_total_scale"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ME_DF_AVG['site'] = 'ME'
GA_DF_AVG['site'] = 'GA'
FL_DF_AVG['site'] = 'FL'

all_df_avg = pd.concat([ME_DF_AVG, GA_DF_AVG, FL_DF_AVG], axis=0)

# %%
ME_DF_AVG.columns.sort_values()
# Out:
# Index(['CHL (ug/l)', 'CHL QF', 'CO2 Air QF', 'CO2 SW QF', 'DOXY (umol/kg)',
#        'DOXY QF', 'H2O Air (mmol/mol)', 'H2O SW (mmol/mol)', 'Latitude',
#        'Licor Atm Pressure (hPa)', 'Licor Temp (C)', 'Longitude', 'MAPCO2 %O2',
#        'NTU (NTU)', 'NTU QF', 'QF_pH', 'SST (C)', 'Salinity', 'dfCO2', 'dpCO2',
#        'fCO2 Air (sat) (uatm)', 'fCO2 SW (sat) (uatm)',
#        'pCO2 Air (sat) (uatm)', 'pCO2 SW (sat) (uatm)', 'pH QF', 'pH_QF',
#        'pH_total_scale', 'site', 'xCO2 Air (dry) (umol/mol)',
#        'xCO2 Air (wet) (umol/mol)', 'xCO2 SW (dry) (umol/mol)',
#        'xCO2 SW (wet) (umol/mol)'],
#       dtype='object')

# %%
FL_DF_AVG.columns.sort_values()
# Out:
# Index(['% O2', 'CHL (ug/l)', 'CHL QF', 'CO2 Air QF', 'CO2 SW QF', 'DOXY',
#        'DOXY QF', 'H2O (mmol/mol)', 'H2O (mmol/mol).1', 'H2O Air (mmol/mol)',
#        'H2O SW (mmol/mol)', 'Latitude', 'Licor Atm Pressure (hPa)',
#        'Licor Temp (C)', 'Longitude', 'MAPCO2 %O2', 'NTU', 'NTU QF', 'PH_QF',
#        'QF', 'QF.1', 'QF_pH', 'SST (C)', 'Salinity', 'dfCO2', 'dpCO2',
#        'fCO2 Air (sat) (uatm)', 'fCO2 SW (sat) (uatm)',
#        'pCO2 Air (sat) (uatm)', 'pCO2 SW (sat) (uatm)', 'pH QF', 'pH SW',
#        'pH_Total_Scale', 'pH_total_scale', 'site',
#        'xCO2  Air (wet) (umol/mol)', 'xCO2  SW (dry) (umol/mol)',
#        'xCO2  SW (wet) (umol/mol)', 'xCO2 Air (dry) (umol/mol)',
#        'xCO2 Air (wet) (umol/mol)', 'xCO2 SW (dry) (umol/mol)',
#        'xCO2 SW (wet) (umol/mol)'],
#       dtype='object')

# %%
FL_DF_AVG['pH_Total_Scale'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
me_cols = {
    
}

ME_DF_AVG.rename(columns=me_cols, inplace=True)
ME_DF_AVG.columns.sort_values()

ME_DF_AVG
# Out:
#             Latitude  Longitude  xCO2 SW (wet) (umol/mol)  CO2 SW QF  \
# Date
# 2010-09-08    43.025    -70.537                406.442857        2.0
# 2010-09-09    43.025    -70.537                401.162500        2.0
# 2010-09-10    43.025    -70.537                397.825000        2.0
# 2010-09-11    43.025    -70.537                389.912500        2.0
# 2010-09-12    43.025    -70.537                387.662500        2.0
# ...              ...        ...                       ...        ...
# 2018-08-08    43.020    -70.543                457.800000        2.0
# 2018-08-09    43.020    -70.543                451.100000        2.0
# 2018-08-10    43.020    -70.543                441.550000        2.0
# 2018-08-11    43.020    -70.543                431.971429        2.0
# 2018-08-12    43.020    -70.543                418.100000        2.0
#
#             H2O SW (mmol/mol)  xCO2 Air (wet) (umol/mol)  CO2 Air QF  \
# Date
# 2010-09-08           4.417143                 389.442857         2.0
# 2010-09-09           4.375000                 390.225000         2.0
# 2010-09-10           4.270000                 387.600000         2.0
# 2010-09-11           4.343750                 388.237500         2.0
# 2010-09-12           4.125000                 381.950000         2.0
# ...                       ...                        ...         ...
# 2018-08-08           5.743750                 428.325000         2.0
# 2018-08-09           5.573333                 415.466667         2.0
# 2018-08-10           5.557500                 425.550000         2.0
# 2018-08-11           4.980000                 409.528571         2.0
# 2018-08-12           4.660000                 395.700000         2.0
#
#             H2O Air (mmol/mol)  Licor Atm Pressure (hPa)  Licor Temp (C)  ...  \
# Date                                                                      ...
# 2010-09-08            4.508571                999.600000       19.785714  ...
# 2010-09-09            3.937500                995.537500       19.425000  ...
# 2010-09-10            3.638750                998.087500       18.912500  ...
# 2010-09-11            3.650000               1005.612500       18.900000  ...
# 2010-09-12            3.556250               1011.637500       18.800000  ...
# ...                        ...                       ...             ...  ...
# 2018-08-08            5.715000               1011.700000       21.987500  ...
# 2018-08-09            5.523333               1008.333333       22.533333  ...
# 2018-08-10            5.492500               1009.400000       21.175000  ...
# 2018-08-11            4.772857               1015.342857       20.928571  ...
# 2018-08-12            4.550000               1017.900000       19.600000  ...
#
#             pH_QF  CHL (ug/l)    CHL QF  NTU (NTU)  NTU QF  DOXY (umol/kg)  \
# Date
# 2010-09-08    2.0 -713.444286  4.142857   0.527143     2.0      231.085714
# 2010-09-09    2.0 -749.157500  4.250000   0.483125     2.0      233.312500
# 2010-09-10    2.0 -749.155000  4.250000   0.441875     2.0      234.737500
# 2010-09-11    2.0 -749.172500  4.250000   0.406875     2.0      235.687500
# 2010-09-12    2.0 -749.187500  4.250000   0.383750     2.0      233.037500
# ...           ...         ...       ...        ...     ...             ...
# 2018-08-08    NaN         NaN       NaN        NaN     NaN             NaN
# 2018-08-09    NaN         NaN       NaN        NaN     NaN             NaN
# 2018-08-10    NaN         NaN       NaN        NaN     NaN             NaN
# 2018-08-11    NaN         NaN       NaN        NaN     NaN             NaN
# 2018-08-12    NaN         NaN       NaN        NaN     NaN             NaN
#
#             DOXY QF  QF_pH  pH QF  site
# Date
# 2010-09-08      2.0    NaN    NaN    ME
# 2010-09-09      2.0    NaN    NaN    ME
# 2010-09-10      2.0    NaN    NaN    ME
# 2010-09-11      2.0    NaN    NaN    ME
# 2010-09-12      2.0    NaN    NaN    ME
# ...             ...    ...    ...   ...
# 2018-08-08      NaN    NaN    2.0    ME
# 2018-08-09      NaN    NaN    2.0    ME
# 2018-08-10      NaN    NaN    2.0    ME
# 2018-08-11      NaN    NaN    2.0    ME
# 2018-08-12      NaN    NaN    2.0    ME
#
# [1127 rows x 32 columns]

# %%
all_df_avg[all_df_avg['CO2 SW QF']== 2]
# Out:
#             Latitude  Longitude  xCO2 SW (wet) (umol/mol)  CO2 SW QF  \
# Date
# 2010-09-08    43.025    -70.537                406.442857        2.0
# 2010-09-09    43.025    -70.537                401.162500        2.0
# 2010-09-10    43.025    -70.537                397.825000        2.0
# 2010-09-11    43.025    -70.537                389.912500        2.0
# 2010-09-12    43.025    -70.537                387.662500        2.0
# ...              ...        ...                       ...        ...
# 2014-06-11    24.898    -80.618                       NaN        2.0
# 2017-03-30    24.898    -80.618                343.833333        2.0
# 2017-03-31    24.898    -80.618                341.900000        2.0
# 2017-04-01    24.898    -80.618                366.612500        2.0
# 2017-04-02    24.898    -80.618                345.900000        2.0
#
#             H2O SW (mmol/mol)  xCO2 Air (wet) (umol/mol)  CO2 Air QF  \
# Date
# 2010-09-08           4.417143                 389.442857         2.0
# 2010-09-09           4.375000                 390.225000         2.0
# 2010-09-10           4.270000                 387.600000         2.0
# 2010-09-11           4.343750                 388.237500         2.0
# 2010-09-12           4.125000                 381.950000         2.0
# ...                       ...                        ...         ...
# 2014-06-11          17.045000                        NaN         2.0
# 2017-03-30           9.136667                 404.933333         2.0
# 2017-03-31           9.285000                 404.987500         2.0
# 2017-04-01           9.215000                 406.112500         2.0
# 2017-04-02           5.660000                 406.500000         2.0
#
#             H2O Air (mmol/mol)  Licor Atm Pressure (hPa)  Licor Temp (C)  ...  \
# Date                                                                      ...
# 2010-09-08            4.508571                999.600000       19.785714  ...
# 2010-09-09            3.937500                995.537500       19.425000  ...
# 2010-09-10            3.638750                998.087500       18.912500  ...
# 2010-09-11            3.650000               1005.612500       18.900000  ...
# 2010-09-12            3.556250               1011.637500       18.800000  ...
# ...                        ...                       ...             ...  ...
# 2014-06-11           14.390000               1015.650000       32.900000  ...
# 2017-03-30            8.060000               1015.466667       26.333333  ...
# 2017-03-31            8.383750               1014.212500       26.612500  ...
# 2017-04-01            8.648750               1015.075000       27.862500  ...
# 2017-04-02            4.470000               1016.400000       31.000000  ...
#
#             xCO2  Air (wet) (umol/mol)  xCO2  SW (dry) (umol/mol)  \
# Date
# 2010-09-08                         NaN                        NaN
# 2010-09-09                         NaN                        NaN
# 2010-09-10                         NaN                        NaN
# 2010-09-11                         NaN                        NaN
# 2010-09-12                         NaN                        NaN
# ...                                ...                        ...
# 2014-06-11                      392.45                      362.6
# 2017-03-30                         NaN                        NaN
# 2017-03-31                         NaN                        NaN
# 2017-04-01                         NaN                        NaN
# 2017-04-02                         NaN                        NaN
#
#             pH_Total_Scale  PH_QF  QF  H2O (mmol/mol)  QF.1  H2O (mmol/mol).1  \
# Date
# 2010-09-08             NaN    NaN NaN             NaN   NaN               NaN
# 2010-09-09             NaN    NaN NaN             NaN   NaN               NaN
# 2010-09-10             NaN    NaN NaN             NaN   NaN               NaN
# 2010-09-11             NaN    NaN NaN             NaN   NaN               NaN
# 2010-09-12             NaN    NaN NaN             NaN   NaN               NaN
# ...                    ...    ...  ..             ...   ...               ...
# 2014-06-11             NaN    NaN NaN             NaN   NaN               NaN
# 2017-03-30             NaN    NaN NaN             NaN   NaN               NaN
# 2017-03-31             NaN    NaN NaN             NaN   NaN               NaN
# 2017-04-01             NaN    NaN NaN             NaN   NaN               NaN
# 2017-04-02             NaN    NaN NaN             NaN   NaN               NaN
#
#             % O2  pH SW
# Date
# 2010-09-08   NaN    NaN
# 2010-09-09   NaN    NaN
# 2010-09-10   NaN    NaN
# 2010-09-11   NaN    NaN
# 2010-09-12   NaN    NaN
# ...          ...    ...
# 2014-06-11   NaN    NaN
# 2017-03-30   NaN    NaN
# 2017-03-31   NaN    NaN
# 2017-04-01   NaN    NaN
# 2017-04-02   NaN    NaN
#
# [2208 rows x 45 columns]

# %%
# all_df_avg[['Latitude', 'Longitude', 'xCO2  SW (wet) (umol/mol)', 'CO2 SW QF',
#         'xCO2  Air (wet) (umol/mol)', 'CO2 Air QF', 'SST (C)', 'Salinity', 'xCO2  SW (dry) (umol/mol)',
#         'dfCO2', 'dpCO2', 'pH_total_scale', 'pH_QF', 'NTU', 'NTU QF', 'DOXY', 'DOXY QF', 'QF_pH', 'pH QF',
#        'xCO2 SW (wet) (umol/mol)', 'xCO2 Air (wet) (umol/mol)',
#         'xCO2 SW (dry) (umol/mol)',
#        'xCO2 Air (dry) (umol/mol)', 'fCO2 SW (sat) uatm',
#        'fCO2 Air (sat) uatm', 'fCO2 SW (sat) (uatm)', 'fCO2 Air (sat) (uatm)',
#        'pCO2 SW (sat) (uatm)', 'pCO2 Air (sat) (uatm)', 'DOXY (umol/kg)', 'site', 'PH_QF', 'QF',
#        'QF.1']]
